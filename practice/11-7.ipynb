# %%
# 넘파이, 판다스, 매트플랏립 실습

import numpy as np
import pandas as pd
import matplotlib

# %%
data = np.random.rand(50)
data
# Out:
# array([0.52047668, 0.47727597, 0.34845007, 0.58314012, 0.91273357,
#        0.20573523, 0.39807137, 0.2486652 , 0.55396883, 0.30088652,
#        0.54682205, 0.06602949, 0.36055756, 0.54909918, 0.17701715,
#        0.7327625 , 0.3912063 , 0.70323082, 0.92605918, 0.32981561,
#        0.24383262, 0.17214777, 0.66436363, 0.19377255, 0.63000275,
#        0.22531654, 0.06430559, 0.90133686, 0.55525763, 0.77469283,
#        0.81201808, 0.82676207, 0.89472041, 0.17608788, 0.72034418,
#        0.8663783 , 0.46593288, 0.76647352, 0.68513229, 0.21596152,
#        0.06606416, 0.56025953, 0.32852491, 0.8616482 , 0.41402798,
#        0.17478642, 0.66143701, 0.91678102, 0.20406721, 0.01292627])

# %%
seri = pd.Series(data)
seri
# Out:
# 0     0.520477
# 1     0.477276
# 2     0.348450
# 3     0.583140
# 4     0.912734
# 5     0.205735
# 6     0.398071
# 7     0.248665
# 8     0.553969
# 9     0.300887
# 10    0.546822
# 11    0.066029
# 12    0.360558
# 13    0.549099
# 14    0.177017
# 15    0.732762
# 16    0.391206
# 17    0.703231
# 18    0.926059
# 19    0.329816
# 20    0.243833
# 21    0.172148
# 22    0.664364
# 23    0.193773
# 24    0.630003
# 25    0.225317
# 26    0.064306
# 27    0.901337
# 28    0.555258
# 29    0.774693
# 30    0.812018
# 31    0.826762
# 32    0.894720
# 33    0.176088
# 34    0.720344
# 35    0.866378
# 36    0.465933
# 37    0.766474
# 38    0.685132
# 39    0.215962
# 40    0.066064
# 41    0.560260
# 42    0.328525
# 43    0.861648
# 44    0.414028
# 45    0.174786
# 46    0.661437
# 47    0.916781
# 48    0.204067
# 49    0.012926
# dtype: float64

# %%
seri.plot()
# Out:
# <AxesSubplot:>
