# %%
import pandas as pd

# %%
data = pd.read_csv('C:\git\python\Practice\data\교통사고 통계_20171231.csv', encoding='EUC-KR')

# %%
data
# Out:
#      월 주야   사고건수  사망자수  중상자수   경상자수  부상신고자수
# 0    1  야   7615   170  2750   8223     755
# 1    1  주   9355   183  3469   9936     966
# 2    2  야   6613   151  2352   7060     650
# 3    2  주   8219   129  2997   8528     736
# 4    3  야   7300   168  2669   7420     707
# 5    3  주   9747   127  3599   9737     914
# 6    4  야   7185   146  2557   7500     763
# 7    4  주  10532   147  3953  10738    1019
# 8    5  야   7276   173  2610   7314     800
# 9    5  주  11226   193  4274  11179    1091
# 10   6  야   7221   144  2586   7309     723
# 11   6  주  10826   171  3992  10778    1066
# 12   7  야   7663   187  2623   8026     796
# 13   7  주  10495   170  3764  11079    1074
# 14   8  야   7747   165  2757   8068     801
# 15   8  주  10935   188  3956  11540    1040
# 16   9  야   8038   214  2860   8056     803
# 17   9  주  11853   205  4255  12134    1263
# 18  10  야   8007   222  3008   8383     836
# 19  10  주  10856   198  4076  11317    1078
# 20  11  야   8009   176  2780   8373     744
# 21  11  주  11368   203  4061  11451    1063
# 22  12  야   8092   193  2746   8690     785
# 23  12  주  10157   162  3518  10361     944

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   월       24 non-null     int64
#  1   주야      24 non-null     object
#  2   사고건수    24 non-null     int64
#  3   사망자수    24 non-null     int64
#  4   중상자수    24 non-null     int64
#  5   경상자수    24 non-null     int64
#  6   부상신고자수  24 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.4+ KB

# %%
data.shape
# Out:
# (24, 7)

# %%
data.columns
# Out:
# Index(['월', '주야', '사고건수', '사망자수', '중상자수', '경상자수', '부상신고자수'], dtype='object')

# %%
data.values
# Out:
# array([[1, '야', 7615, 170, 2750, 8223, 755],
#        [1, '주', 9355, 183, 3469, 9936, 966],
#        [2, '야', 6613, 151, 2352, 7060, 650],
#        [2, '주', 8219, 129, 2997, 8528, 736],
#        [3, '야', 7300, 168, 2669, 7420, 707],
#        [3, '주', 9747, 127, 3599, 9737, 914],
#        [4, '야', 7185, 146, 2557, 7500, 763],
#        [4, '주', 10532, 147, 3953, 10738, 1019],
#        [5, '야', 7276, 173, 2610, 7314, 800],
#        [5, '주', 11226, 193, 4274, 11179, 1091],
#        [6, '야', 7221, 144, 2586, 7309, 723],
#        [6, '주', 10826, 171, 3992, 10778, 1066],
#        [7, '야', 7663, 187, 2623, 8026, 796],
#        [7, '주', 10495, 170, 3764, 11079, 1074],
#        [8, '야', 7747, 165, 2757, 8068, 801],
#        [8, '주', 10935, 188, 3956, 11540, 1040],
#        [9, '야', 8038, 214, 2860, 8056, 803],
#        [9, '주', 11853, 205, 4255, 12134, 1263],
#        [10, '야', 8007, 222, 3008, 8383, 836],
#        [10, '주', 10856, 198, 4076, 11317, 1078],
#        [11, '야', 8009, 176, 2780, 8373, 744],
#        [11, '주', 11368, 203, 4061, 11451, 1063],
#        [12, '야', 8092, 193, 2746, 8690, 785],
#        [12, '주', 10157, 162, 3518, 10361, 944]], dtype=object)

# %%
data.head()
# Out:
#    월 주야  사고건수  사망자수  중상자수  경상자수  부상신고자수
# 0  1  야  7615   170  2750  8223     755
# 1  1  주  9355   183  3469  9936     966
# 2  2  야  6613   151  2352  7060     650
# 3  2  주  8219   129  2997  8528     736
# 4  3  야  7300   168  2669  7420     707

# %%
data.tail(9)
# Out:
#      월 주야   사고건수  사망자수  중상자수   경상자수  부상신고자수
# 15   8  주  10935   188  3956  11540    1040
# 16   9  야   8038   214  2860   8056     803
# 17   9  주  11853   205  4255  12134    1263
# 18  10  야   8007   222  3008   8383     836
# 19  10  주  10856   198  4076  11317    1078
# 20  11  야   8009   176  2780   8373     744
# 21  11  주  11368   203  4061  11451    1063
# 22  12  야   8092   193  2746   8690     785
# 23  12  주  10157   162  3518  10361     944

# %%
data.rename(columns={'주야': '유형'}, inplace=True)
data.head()
# Out:
#    월 유형  사고건수  사망자수  중상자수  경상자수  부상신고자수
# 0  1  야  7615   170  2750  8223     755
# 1  1  주  9355   183  3469  9936     966
# 2  2  야  6613   151  2352  7060     650
# 3  2  주  8219   129  2997  8528     736
# 4  3  야  7300   168  2669  7420     707

# %%
# None 제거
new_data = data.dropna()
new_data
# Out:
#      월 유형   사고건수  사망자수  중상자수   경상자수  부상신고자수
# 0    1  야   7615   170  2750   8223     755
# 1    1  주   9355   183  3469   9936     966
# 2    2  야   6613   151  2352   7060     650
# 3    2  주   8219   129  2997   8528     736
# 4    3  야   7300   168  2669   7420     707
# 5    3  주   9747   127  3599   9737     914
# 6    4  야   7185   146  2557   7500     763
# 7    4  주  10532   147  3953  10738    1019
# 8    5  야   7276   173  2610   7314     800
# 9    5  주  11226   193  4274  11179    1091
# 10   6  야   7221   144  2586   7309     723
# 11   6  주  10826   171  3992  10778    1066
# 12   7  야   7663   187  2623   8026     796
# 13   7  주  10495   170  3764  11079    1074
# 14   8  야   7747   165  2757   8068     801
# 15   8  주  10935   188  3956  11540    1040
# 16   9  야   8038   214  2860   8056     803
# 17   9  주  11853   205  4255  12134    1263
# 18  10  야   8007   222  3008   8383     836
# 19  10  주  10856   198  4076  11317    1078
# 20  11  야   8009   176  2780   8373     744
# 21  11  주  11368   203  4061  11451    1063
# 22  12  야   8092   193  2746   8690     785
# 23  12  주  10157   162  3518  10361     944

# %%
new_data.loc[6]
# Out:
# 월            4
# 유형           야
# 사고건수      7185
# 사망자수       146
# 중상자수      2557
# 경상자수      7500
# 부상신고자수     763
# Name: 6, dtype: object

# %%
new_data.iloc[6]
# Out:
# 월            4
# 유형           야
# 사고건수      7185
# 사망자수       146
# 중상자수      2557
# 경상자수      7500
# 부상신고자수     763
# Name: 6, dtype: object

# %%
new_data.set_index('월', inplace=True)
new_data
# Out:
#    유형   사고건수  사망자수  중상자수   경상자수  부상신고자수
# 월
# 1   야   7615   170  2750   8223     755
# 1   주   9355   183  3469   9936     966
# 2   야   6613   151  2352   7060     650
# 2   주   8219   129  2997   8528     736
# 3   야   7300   168  2669   7420     707
# 3   주   9747   127  3599   9737     914
# 4   야   7185   146  2557   7500     763
# 4   주  10532   147  3953  10738    1019
# 5   야   7276   173  2610   7314     800
# 5   주  11226   193  4274  11179    1091
# 6   야   7221   144  2586   7309     723
# 6   주  10826   171  3992  10778    1066
# 7   야   7663   187  2623   8026     796
# 7   주  10495   170  3764  11079    1074
# 8   야   7747   165  2757   8068     801
# 8   주  10935   188  3956  11540    1040
# 9   야   8038   214  2860   8056     803
# 9   주  11853   205  4255  12134    1263
# 10  야   8007   222  3008   8383     836
# 10  주  10856   198  4076  11317    1078
# 11  야   8009   176  2780   8373     744
# 11  주  11368   203  4061  11451    1063
# 12  야   8092   193  2746   8690     785
# 12  주  10157   162  3518  10361     944

# %%
new_data.loc['3']
# Out:
#   유형  사고건수  사망자수  중상자수  경상자수  부상신고자수
# 월
# 3  야  7300   168  2669  7420     707
# 3  주  9747   127  3599  9737     914

# %%
monthly_accident_counts = new_data.drop(columns=['유형'])
monthly_accident_counts
# Out:
#      사고건수  사망자수  중상자수   경상자수  부상신고자수
# 월
# 1    7615   170  2750   8223     755
# 1    9355   183  3469   9936     966
# 2    6613   151  2352   7060     650
# 2    8219   129  2997   8528     736
# 3    7300   168  2669   7420     707
# 3    9747   127  3599   9737     914
# 4    7185   146  2557   7500     763
# 4   10532   147  3953  10738    1019
# 5    7276   173  2610   7314     800
# 5   11226   193  4274  11179    1091
# 6    7221   144  2586   7309     723
# 6   10826   171  3992  10778    1066
# 7    7663   187  2623   8026     796
# 7   10495   170  3764  11079    1074
# 8    7747   165  2757   8068     801
# 8   10935   188  3956  11540    1040
# 9    8038   214  2860   8056     803
# 9   11853   205  4255  12134    1263
# 10   8007   222  3008   8383     836
# 10  10856   198  4076  11317    1078
# 11   8009   176  2780   8373     744
# 11  11368   203  4061  11451    1063
# 12   8092   193  2746   8690     785
# 12  10157   162  3518  10361     944

# %%
del new_data

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
day_counts = monthly_accident_counts['사고건수']
day_counts
# Out:
# 월
# 1      7615
# 1      9355
# 2      6613
# 2      8219
# 3      7300
# 3      9747
# 4      7185
# 4     10532
# 5      7276
# 5     11226
# 6      7221
# 6     10826
# 7      7663
# 7     10495
# 8      7747
# 8     10935
# 9      8038
# 9     11853
# 10     8007
# 10    10856
# 11     8009
# 11    11368
# 12     8092
# 12    10157
# Name: 사고건수, dtype: int64

# %%
type(day_counts)
# Out:
# pandas.core.series.Series

# %%
day_counts.plot.line()
# Out:
# <AxesSubplot:xlabel='월'>

# %%
day_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='월'>

# %%
monthly_accident_counts.plot.line()
# Out:
# <AxesSubplot:xlabel='월'>

# %%
monthly_accident_counts.plot.bar()
# Out:
# <AxesSubplot:xlabel='월'>
